# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('java.csv',delimiter='|',quotechar='"')
# Out:
# C:\ANACONDA\lib\site-packages\IPython\core\interactiveshell.py:3049: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#                                                 job_title        job_id  \
# 0                       Java Developer/Sr. Java Developer   70820500303
# 1           Lead Software Engineer ( Lead Java Developer)   70820904640
# 2            Virtusa Hiring For Core Java Developer, Pune  270720000183
# 3                                   Senior Java Developer   30820002140
# 4                  Senior Java Developer / Java Developer   40820001875
# 5       Senior Full Stack Java Developer-Flexcube Prod...  140720000266
# 6          App Dev & Support Engineer II - JAVA Developer   30720001777
# 7       Senior Software Engineer -Full Stack Java Deve...   60820500538
# 8                                       Sr Java Developer   40820904094
# 9          Software Development Engineer (Java developer)  300620000494
# 10      Hiring For Java Sr Developer/Lead: Banking Pro...   40820003468
# 11                        Core Java Developer - J2ee/oops  201119907024
# ...

# %%
df['experience_level'].replace({' Yrs':''},inplace=True,regex=True)

# %%
x=df['experience_level'].value_counts().sort_values(ascending=False)

# %%
x=x.head(20)

# %%
x
# Out:
# 2-5     8804
# 2-7     7641
# 3-8     6865
# 5-10    6143
# 3-5     4811
# 3-6     4657
# 1-3     4391
# 4-9     3826
# 2-4     3705
# 1-5     3702
# 2-6     3363
# 0-1     3071
# 1-6     3025
# 3-7     2900
# 4-8     2791
# 1-4     2687
# 5-8     2453
# 4-6     2327
# 1-2     2002
# 0-2     1972
# Name: experience_level, dtype: int64

# %%
x.plot(kind='pie')
